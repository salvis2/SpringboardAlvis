# %% [markdown]
# # League of Legends Item Balancing
# ### Capstone Project 1: Data Wrangling
#
# This documents the process I used to acquire the data for this project.
#
# Some data will be acquired from the Riot Games Static API: https://ddragonexplorer.com/cdn/. This doesn't require a login.
#
# The rest will be acquired from the Riot Games API: https://developer.riotgames.com/api-methods/. This does require a login. If you have an account for League of Legends, that will work.

# %%
import requests
import json
import math
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import time

# %%
# Do not store the API Key in a publicly available document :)
RIOT_API_KEY = 'RGAPI-09384eca-b5bd-4cbd-ba09-a46e2bdf76f0'

# %%
params = {'api_key': RIOT_API_KEY}

# %% [markdown]
# ### TEST DATA PIPELINE
#
# I walked through the whole process of acquiring match data with one data point, so I could troubleshoot and develop the method more quickly.
#
# The process goes from league IDs to summoner IDs to account IDs to match histories to matches themselves.

# %% [markdown]
# Example Request to get an account ID from a summoner ID

# %%
account_request_link = 'https://na1.api.riotgames.com/lol/summoner/v4/summoners/' + 'F2deh05bxktXmEGhSR1Onfa-mIL_lmHYatpKnLZGGEE-5qo'
account = requests.get(account_request_link, params=params)
accounts_df = json_normalize(account.json())
accounts_df
# Out:
#                                            accountId  \
# 0  H2UztO5Jzus8wtCEm-4x3xy-s0B3a24-Y8O8qHmPAHOCb1...
#
#                                                 id       name  profileIconId  \
# 0  F2deh05bxktXmEGhSR1Onfa-mIL_lmHYatpKnLZGGEE-5qo  Zen Sano             770
#
#                                                puuid   revisionDate  \
# 0  txkJECCheRbC-lI41l0bZxkFnKGTvr6RSNUGa-6eY521sJ...  1550494712000
#
#    summonerLevel
# 0             76

# %% [markdown]
# Example Request to get a match from a game ID. Game IDs can be found in match histories.

# %%
match_history_request_link ='https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/'+'H2UztO5Jzus8wtCEm-4x3xy-s0B3a24-Y8O8qHmPAHOCb1CcJxYtxjz2'+'?queue=420'
match_history = requests.get(match_history_request_link, params=params)
json_normalize(match_history.json()['matches'][0])
# Out:
#    champion      gameId lane platformId  queue  role  season      timestamp
# 0       517  2980510552  TOP        NA1    420  SOLO      13  1550492534969

# %%
match_data_request_link = 'https://na1.api.riotgames.com/lol/match/v4/matches/' + str(int(2923933470L))
match_data = requests.get(match_data_request_link, params=params)
json_normalize(match_data.json(), record_path=['participants'], meta=['gameDuration'])
# Out:
#    championId highestAchievedSeasonTier  participantId  spell1Id  spell2Id  \
# 0         497                      GOLD              1         4         3
# 1          20                  PLATINUM              2         4        11
# 2           7                      GOLD              3         4        14
# 3         202                  PLATINUM              4         7         4
# 4          92                  PLATINUM              5        14         4
# 5         236                  PLATINUM              6         7         4
# 6         412                      GOLD              7        14         4
# 7          86                  UNRANKED              8         4        14
# 8         164                  UNRANKED              9         4        11
# 9          38                  UNRANKED             10         4        12
#
#                                                stats  teamId  \
# 0  {u'neutralMinionsKilledTeamJungle': 0, u'visio...     100
# 1  {u'neutralMinionsKilledTeamJungle': 40, u'visi...     100
# 2  {u'neutralMinionsKilledTeamJungle': 8, u'visio...     100
# 3  {u'neutralMinionsKilledTeamJungle': 4, u'visio...     100
# 4  {u'neutralMinionsKilledTeamJungle': 4, u'visio...     100
# 5  {u'neutralMinionsKilledTeamJungle': 0, u'visio...     200
# 6  {u'neutralMinionsKilledTeamJungle': 0, u'visio...     200
# 7  {u'neutralMinionsKilledTeamJungle': 0, u'visio...     200
# 8  {u'neutralMinionsKilledTeamJungle': 55, u'visi...     200
# 9  {u'neutralMinionsKilledTeamJungle': 0, u'visio...     200
#
#                                             timeline  gameDuration
# 0  {u'lane': u'NONE', u'participantId': 1, u'csDi...          1191
# 1  {u'lane': u'NONE', u'participantId': 2, u'csDi...          1191
# 2  {u'lane': u'NONE', u'participantId': 3, u'csDi...          1191
# 3  {u'lane': u'NONE', u'participantId': 4, u'csDi...          1191
# 4  {u'lane': u'NONE', u'participantId': 5, u'csDi...          1191
# 5  {u'lane': u'NONE', u'participantId': 6, u'csDi...          1191
# 6  {u'lane': u'NONE', u'participantId': 7, u'csDi...          1191
# 7  {u'lane': u'NONE', u'participantId': 8, u'csDi...          1191
# 8  {u'lane': u'NONE', u'participantId': 9, u'csDi...          1191
# 9  {u'lane': u'NONE', u'participantId': 10, u'csD...          1191

# %% [markdown]
# Test Request. This request path gets the overall match information, for a given match id. While this has the set of items each player bought, the main information this may be missing is when each item was bought. This may be an important variable, and would require another request to find.

# %% [markdown]
# Using json_normalize took me a while to figure out.
#
# Here is how not to use json_normalize:

# %%
match = json_normalize(match_data.json(), record_path=['participants'], meta=['gameId'])
match.head(2)
# Out:
#    championId highestAchievedSeasonTier  participantId  spell1Id  spell2Id  \
# 0         497                      GOLD              1         4         3
# 1          20                  PLATINUM              2         4        11
#
#                                                stats  teamId  \
# 0  {u'neutralMinionsKilledTeamJungle': 0, u'visio...     100
# 1  {u'neutralMinionsKilledTeamJungle': 40, u'visi...     100
#
#                                             timeline      gameId
# 0  {u'lane': u'NONE', u'participantId': 1, u'csDi...  2923933470
# 1  {u'lane': u'NONE', u'participantId': 2, u'csDi...  2923933470

# %% [markdown]
# Most of the information I want is inside the stats column: I want that flattened.
#
# The record_path / meta parameters think that you are leading them to rows. The entries should actually be columns. If I need multiple subsets of the full json, I will need to join them together. This is the correct way to use json_normalize:

# %%
match_stats = json_normalize(match_data.json()['participants'])
match_stats[match_stats['participantId'] == 1][['stats.item0', 'stats.item1',
                                                'stats.item2', 'stats.item'+'3',
                                                'stats.item4', 'stats.item5', 'stats.item6']]
# Out:
#    stats.item0  stats.item1  stats.item2  stats.item3  stats.item4  \
# 0         3098         3174            0         3117            0
#
#    stats.item5  stats.item6
# 0            0         3364

# %% [markdown]
# Above is a set of items at the end of a game. 4 of the 7 inventory slots have something in them, and 3 have nothing.
#
# Below is an example of the full match data. There is a lot to work with, more than I will probably use.

# %%
match_stats
# Out:
#    championId highestAchievedSeasonTier  participantId  spell1Id  spell2Id  \
# 0         497                      GOLD              1         4         3
# 1          20                  PLATINUM              2         4        11
# 2           7                      GOLD              3         4        14
# 3         202                  PLATINUM              4         7         4
# 4          92                  PLATINUM              5        14         4
# 5         236                  PLATINUM              6         7         4
# 6         412                      GOLD              7        14         4
# 7          86                  UNRANKED              8         4        14
# 8         164                  UNRANKED              9         4        11
# 9          38                  UNRANKED             10         4        12
#
#    stats.assists  stats.champLevel  stats.combatPlayerScore  \
# 0              7                 9                        0
# 1              6                11                        0
# 2              2                12                        0
# 3              4                10                        0
# 4              2                12                        0
# 5             10                11                        0
# 6             14                10                        0
# 7              4                13                        0
# 8              3                12                        0
# 9              8                11                        0
#
#    stats.damageDealtToObjectives  stats.damageDealtToTurrets  \
# 0                            995                           0
# 1                           7757                           0
# 2                           5347                        3356
# 3                           1135                           0
# 4                           3482                         806
# 5                           7534                        5387
# 6                           3871                        2484
# 7                           6792                        6792
# 8                          26022                        4048
# 9                           3712                        2661
#
#                ...               timeline.creepsPerMinDeltas.0-10  \
# 0              ...                                            0.2
# 1              ...                                            0.8
# 2              ...                                            4.8
# 3              ...                                            5.5
# 4              ...                                            5.8
# 5              ...                                            7.2
# 6              ...                                            0.0
# 7              ...                                            7.1
# 8              ...                                            1.7
# 9              ...                                            6.2
#
#    timeline.csDiffPerMinDeltas.0-10  \
# 0                             -1.02
# 1                             -1.02
# 2                             -1.02
# 3                             -1.02
# 4                             -1.02
# 5                              1.02
# 6                              1.02
# 7                              1.02
# 8                              1.02
# 9                              1.02
#
#    timeline.damageTakenDiffPerMinDeltas.0-10  \
# 0                                     -25.92
# 1                                     -25.92
# 2                                     -25.92
# 3                                     -25.92
# 4                                     -25.92
# 5                                      25.92
# 6                                      25.92
# 7                                      25.92
# 8                                      25.92
# 9                                      25.92
#
#    timeline.damageTakenPerMinDeltas.0-10  timeline.goldPerMinDeltas.0-10  \
# 0                                  395.3                           160.9
# 1                                  849.9                           322.3
# 2                                  460.1                           343.2
# 3                                  407.5                           254.8
# 4                                  386.4                           268.0
# 5                                  473.2                           374.6
# 6                                  359.8                           226.6
# 7                                  499.7                           303.4
# 8                                  681.6                           447.7
# 9                                  614.5                           246.8
#
#    timeline.lane  timeline.participantId  timeline.role  \
# 0           NONE                       1    DUO_SUPPORT
# 1           NONE                       2    DUO_SUPPORT
# 2           NONE                       3    DUO_SUPPORT
# 3           NONE                       4    DUO_SUPPORT
# 4           NONE                       5            DUO
# 5           NONE                       6    DUO_SUPPORT
# 6           NONE                       7    DUO_SUPPORT
# 7           NONE                       8    DUO_SUPPORT
# 8           NONE                       9    DUO_SUPPORT
# 9           NONE                      10    DUO_SUPPORT
#
#    timeline.xpDiffPerMinDeltas.0-10  timeline.xpPerMinDeltas.0-10
# 0                            -46.96                         241.1
# 1                            -46.96                         351.3
# 2                            -46.96                         368.5
# 3                            -46.96                         274.5
# 4                            -46.96                         440.1
# 5                             46.96                         364.8
# 6                             46.96                         260.1
# 7                             46.96                         462.2
# 8                             46.96                         403.1
# 9                             46.96                         420.1
#
# [10 rows x 120 columns]

# %% [markdown]
# Example request for a match timeline. Here, I boil down the match events to the items purchased, who purchased what, and when.
#
# This is what I can use for finding the timing data in my join (see below).

# %%
# Request
test_timeline = requests.get('https://na1.api.riotgames.com/lol/match/v4/timelines/by-match/2923933470',
                            params=params)
# Normalization
test_lol_df = json_normalize(test_timeline.json(), ['frames', 'events'])

# Filter the columns I want
test_items_times = test_lol_df[['participantId', 'itemId', 'timestamp', 'type']]

# Extract the timestamp for a certain purchased item
test_items_times[(test_items_times['type'] == 'ITEM_PURCHASED') &
                 (test_items_times['participantId'] == 10) &
                 (test_items_times['itemId'] == 2033)]['timestamp'].values[-1]
# Out:
# 761622

# %% [markdown]
# I need to figure out how to join the the match data with items purchased with the purchase times. The join will attach 7 purchase times onto the row with the corresponding items.
#
# I need logic for the empty item slot (itemId = 0).

# %%
item_timing_col_names = ['participantId', 'item0_time', 'item1_time', 'item2_time',
                         'item3_time', 'item4_time', 'item5_time', 'item6_time']
item_timing_cols = pd.DataFrame(index=np.arange(1,11), columns=item_timing_col_names)

# %%
# This function will get the timestamp for a player and an item slot 0 - 6
def get_item_timestamp( participant_id, item_num ):
    col_name = 'stats.item' + str(item_num)
    
    # No item in this slot
    if (match_stats.loc[participant_id - 1, col_name] == 0):
        return np.nan
    
    # Item in the slot
    else:
        return test_items_times[(test_items_times['type'] == 'ITEM_PURCHASED') &
                         (test_items_times['participantId'] == participant_id) &
                         (test_items_times['itemId'] ==
                          match_stats[match_stats['participantId'] == participant_id][col_name].values[0]
                          )]['timestamp'].values[-1]

# %%
# Find all the timestamps for all players' items
for participant_id in match_stats['participantId']:
    # 7 possible final items with wards
    item_timing_cols.loc[participant_id, 'participantId'] = participant_id
    item_timing_cols.loc[participant_id, 'item0_time'] = get_item_timestamp(participant_id, 0)
    item_timing_cols.loc[participant_id, 'item1_time'] = get_item_timestamp(participant_id, 1)
    item_timing_cols.loc[participant_id, 'item2_time'] = get_item_timestamp(participant_id, 2)
    item_timing_cols.loc[participant_id, 'item3_time'] = get_item_timestamp(participant_id, 3)
    item_timing_cols.loc[participant_id, 'item4_time'] = get_item_timestamp(participant_id, 4)
    item_timing_cols.loc[participant_id, 'item5_time'] = get_item_timestamp(participant_id, 5)
    item_timing_cols.loc[participant_id, 'item6_time'] = get_item_timestamp(participant_id, 6)

# %% [markdown]
# This is the way I will join the match data and the item purchase data. All the way on the right, you can see the item purchase times in milliseconds.

# %%
match_data_with_timing_df = match_stats.join(item_timing_cols, on='participantId', lsuffix='l', rsuffix='r')
match_data_with_timing_df.head()
# Out:
#    championId highestAchievedSeasonTier  participantIdl  spell1Id  spell2Id  \
# 0         497                      GOLD               1         4         3
# 1          20                  PLATINUM               2         4        11
# 2           7                      GOLD               3         4        14
# 3         202                  PLATINUM               4         7         4
# 4          92                  PLATINUM               5        14         4
#
#    stats.assists  stats.champLevel  stats.combatPlayerScore  \
# 0              7                 9                        0
# 1              6                11                        0
# 2              2                12                        0
# 3              4                10                        0
# 4              2                12                        0
#
#    stats.damageDealtToObjectives  stats.damageDealtToTurrets     ...      \
# 0                            995                           0     ...
# 1                           7757                           0     ...
# 2                           5347                        3356     ...
# 3                           1135                           0     ...
# 4                           3482                         806     ...
#
#    timeline.xpDiffPerMinDeltas.0-10  timeline.xpPerMinDeltas.0-10  \
# 0                            -46.96                         241.1
# 1                            -46.96                         351.3
# 2                            -46.96                         368.5
# 3                            -46.96                         274.5
# 4                            -46.96                         440.1
#
#    participantIdr  item0_time  item1_time  item2_time  item3_time  item4_time  \
# 0               1      545171     1092086         NaN      426678         NaN
# 1               2      617417        9046      821830      976572      982902
# 2               3      819322      568416      168238     1003418       11125
# 3               4        4987      179110      844332     1100601      583254
# 4               5      220964      222449      815758      220964      978267
#
#    item5_time  item6_time
# 0         NaN      830271
# 1         NaN        9937
# 2     1013153     1027529
# 3     1000411        5548
# 4      695315       48620
#
# [5 rows x 128 columns]

# %%
match_stats.head()
# Out:
#    championId highestAchievedSeasonTier  participantId  spell1Id  spell2Id  \
# 0         497                      GOLD              1         4         3
# 1          20                  PLATINUM              2         4        11
# 2           7                      GOLD              3         4        14
# 3         202                  PLATINUM              4         7         4
# 4          92                  PLATINUM              5        14         4
#
#    stats.assists  stats.champLevel  stats.combatPlayerScore  \
# 0              7                 9                        0
# 1              6                11                        0
# 2              2                12                        0
# 3              4                10                        0
# 4              2                12                        0
#
#    stats.damageDealtToObjectives  stats.damageDealtToTurrets  \
# 0                            995                           0
# 1                           7757                           0
# 2                           5347                        3356
# 3                           1135                           0
# 4                           3482                         806
#
#                ...               timeline.creepsPerMinDeltas.0-10  \
# 0              ...                                            0.2
# 1              ...                                            0.8
# 2              ...                                            4.8
# 3              ...                                            5.5
# 4              ...                                            5.8
#
#    timeline.csDiffPerMinDeltas.0-10  \
# 0                             -1.02
# 1                             -1.02
# 2                             -1.02
# 3                             -1.02
# 4                             -1.02
#
#    timeline.damageTakenDiffPerMinDeltas.0-10  \
# 0                                     -25.92
# 1                                     -25.92
# 2                                     -25.92
# 3                                     -25.92
# 4                                     -25.92
#
#    timeline.damageTakenPerMinDeltas.0-10  timeline.goldPerMinDeltas.0-10  \
# 0                                  395.3                           160.9
# 1                                  849.9                           322.3
# 2                                  460.1                           343.2
# 3                                  407.5                           254.8
# 4                                  386.4                           268.0
#
#    timeline.lane  timeline.participantId  timeline.role  \
# 0           NONE                       1    DUO_SUPPORT
# 1           NONE                       2    DUO_SUPPORT
# 2           NONE                       3    DUO_SUPPORT
# 3           NONE                       4    DUO_SUPPORT
# 4           NONE                       5            DUO
#
#    timeline.xpDiffPerMinDeltas.0-10  timeline.xpPerMinDeltas.0-10
# 0                            -46.96                         241.1
# 1                            -46.96                         351.3
# 2                            -46.96                         368.5
# 3                            -46.96                         274.5
# 4                            -46.96                         440.1
#
# [5 rows x 120 columns]

# %% [markdown]
# ## Champion Table

# %% [markdown]
# This imports champion basic data: name, role, championId.
#
# I don't end up using it, but it was good practice for extracting the data and manipulating the JSON.
#
# The data was extracted from the static API / Data Dragon.
#
# Here is an example of the data for the champion Aatrox.
#
# Data Dragon is currently down. I hope it comes back soon.

# %%
champions_request = requests.get('https://ddragonexplorer.com/cdn/8.22.1/data/en_US/champion.json')
champions_json = champions_request.json()
champions_json['data']['Aatrox']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9c895689c29d> in <module>()
#       1 champions_request = requests.get('https://ddragonexplorer.com/cdn/8.22.1/data/en_US/champion.json')
# ----> 2 champions_json = champions_request.json()
#       3 champions_json['data']['Aatrox']
#
# C:\Users\sebia\Miniconda2\lib\site-packages\requests\models.pyc in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# C:\Users\sebia\Miniconda2\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# C:\Users\sebia\Miniconda2\lib\json\decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# C:\Users\sebia\Miniconda2\lib\json\decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded

# %% [markdown]
# I build the champion table here. The tricky part is that in order for the formatting of the index to work, I needed to set it after I built the rest of the table.

# %%
# Get index values / champion IDs
champions_idx = [str(key) for key in champions_json['data'].keys()]

# Rest of the df
champions_df = json_normalize(champions_json['data'].values())

# Set the index
champions_df.index = champions_idx
champions_df.index = champions_df.index.rename('champion_name')
champions_df.head()
# Out:
#                                                            blurb          id  \
# champion_name
# MonkeyKing     Wukong is a vastayan trickster who uses his st...  MonkeyKing
# Jax            Unmatched in both his skill with unique armame...         Jax
# Kayn           A peerless practitioner of lethal shadow magic...        Kayn
# Shaco          Crafted long ago as a plaything for a lonely p...       Shaco
# Warwick        Warwick is a monster who hunts the gray alleys...     Warwick
#
#                    image.full image.group  image.h   image.sprite  image.w  \
# champion_name
# MonkeyKing     MonkeyKing.png    champion       48  champion2.png       48
# Jax                   Jax.png    champion       48  champion1.png       48
# Kayn                 Kayn.png    champion       48  champion1.png       48
# Shaco               Shaco.png    champion       48  champion3.png       48
# Warwick           Warwick.png    champion       48  champion4.png       48
#
#                image.x  image.y  info.attack   ...     stats.movespeed  \
# champion_name                                  ...
# MonkeyKing          96       48            8   ...                 345
# Jax                144       48            7   ...                 350
# Kayn               192       96           10   ...                 340
# Shaco              336        0            8   ...                 350
# Warwick            432        0            9   ...                 335
#
#                stats.mp  stats.mpperlevel stats.mpregen stats.mpregenperlevel  \
# champion_name
# MonkeyKing       265.84                38         8.042                 0.650
# Jax              338.80                32         7.576                 0.700
# Kayn             410.00                50        11.500                 0.950
# Shaco            297.20                40         7.156                 0.450
# Warwick          280.00                35         7.466                 0.575
#
#               stats.spellblock  stats.spellblockperlevel                 tags  \
# champion_name
# MonkeyKing                32.1                      1.25      [Fighter, Tank]
# Jax                       32.1                      1.25  [Fighter, Assassin]
# Kayn                      32.1                      1.25  [Fighter, Assassin]
# Shaco                     32.1                      1.25           [Assassin]
# Warwick                   32.1                      1.25      [Fighter, Tank]
#
#                                    title  version
# champion_name
# MonkeyKing               the Monkey King   8.22.1
# Jax                  Grandmaster at Arms   8.22.1
# Kayn                   the Shadow Reaper   8.22.1
# Shaco                   the Demon Jester   8.22.1
# Warwick        the Uncaged Wrath of Zaun   8.22.1
#
# [5 rows x 38 columns]

# %% [markdown]
# This is a nicer way to look at the more relevant parts of this dataframe.

# %%
champion_cols = ['name', 'id', 'key', 'tags', 'info.attack', 'info.defense', 'info.difficulty', 'info.magic']
champions_df_min = champions_df[champion_cols]
champions_df_min.head()
# Out:
#                   name          id  key                 tags  info.attack  \
# champion_name
# MonkeyKing      Wukong  MonkeyKing   62      [Fighter, Tank]            8
# Jax                Jax         Jax   24  [Fighter, Assassin]            7
# Kayn              Kayn        Kayn  141  [Fighter, Assassin]           10
# Shaco            Shaco       Shaco   35           [Assassin]            8
# Warwick        Warwick     Warwick   19      [Fighter, Tank]            9
#
#                info.defense  info.difficulty  info.magic
# champion_name
# MonkeyKing                5                3           2
# Jax                       5                5           7
# Kayn                      6                8           1
# Shaco                     4                9           6
# Warwick                   5                3           3

# %% [markdown]
# ## Item Table

# %% [markdown]
# This imports the item data. I use several columns from it for exploratory data analysis and to help assign item names to otherwise unknown data points.
#
# The request gets the JSON for all purchasable items, acquired from the static API / Data Dragon.
#
# Here is an example item: Targon's Brace.

# %%
items_request = requests.get('https://ddragonexplorer.com/cdn/8.22.1/data/en_US/item.json')
lol_items_json = items_request.json()
lol_items_json['data'].values()[1]
# Out:
# {u'colloq': u";Targon's Brace;Relic Shield;Support",
#  u'description': u'<stats>+60 Health<br>+50% Base Health Regen <br>+3 Gold per 10 seconds </stats><br><br><unique>UNIQUE Passive - Spoils of War:</unique> Melee basic attacks execute minions below 200 (+40 per level) Health. Killing a minion heals the owner and the nearest allied champion for 25 Health (+2% missing health) and grants them kill Gold. 50% healing if the owner is ranged. These effects require a nearby ally. Recharges every 20 seconds. Max 3 charges.<br><br><groupLimit>Limited to 1 Starter item.</groupLimit>',
#  u'effect': {u'Effect10Amount': u'0',
#   u'Effect11Amount': u'5000',
#   u'Effect12Amount': u'20',
#   u'Effect13Amount': u'3',
#   u'Effect14Amount': u'0',
#   u'Effect15Amount': u'40',
#   u'Effect16Amount': u'0.02',
#   u'Effect17Amount': u'0.5',
#   u'Effect18Amount': u'10',
#   u'Effect1Amount': u'200',
#   u'Effect2Amount': u'25',
#   u'Effect3Amount': u'2',
#   u'Effect4Amount': u'0',
#   u'Effect5Amount': u'0',
#   u'Effect6Amount': u'0',
#   u'Effect7Amount': u'0',
#   u'Effect8Amount': u'0',
#   u'Effect9Amount': u'3'},
#  u'gold': {u'base': 400, u'purchasable': True, u'sell': 160, u'total': 400},
#  u'image': {u'full': u'4302.png',
#   u'group': u'item',
#   u'h': 48,
#   u'sprite': u'item3.png',
#   u'w': 48,
#   u'x': 96,
#   u'y': 48},
#  u'maps': {u'10': False, u'11': False, u'12': False},
#  u'name': u'Heart of Targon',
#  u'plaintext': u'Kill minions periodically to heal and grant gold to a nearby ally',
#  u'stats': {u'FlatHPPoolMod': 60},
#  u'tags': [u'Health', u'HealthRegen', u'Aura', u'GoldPer', u'Lane']}

# %% [markdown]
# The tricky part for this dataframe was only wanting certain columns. I named them all out manually, both for their keys in the JSON and for what I wanted the dataframe columns to be called.

# %%
item_cols = ['name', 'description', 'consumed', 'gold.base', 'depth', 'maps.11', 'effect.Effect1Amount', 'effect.Effect2Amount',
             'effect.Effect3Amount', 'effect.Effect4Amount', 'effect.Effect5Amount','effect.Effect6Amount',
             'effect.Effect7Amount', 'effect.Effect8Amount', 'from', 'gold.purchasable', 'gold.total', 'requiredChampion',
             'specialRecipe', 'stacks', 'stats.FlatArmorMod', 'stats.FlatCritChanceMod', 'stats.FlatHPPoolMod',
             'stats.FlatHPRegenMod', 'stats.FlatMagicDamageMod', 'stats.FlatMovementSpeedMod', 'stats.FlatPhysicalDamageMod',
             'stats.FlatSpellBlockMod', 'stats.PercentAttackSpeedMod', 'stats.PercentLifeStealMod',
             'stats.PercentMovementSpeedMod', 'tags']
item_col_names = ['name', 'description', 'consumed', 'base_gold', 'depth', 'sr', 'effect1amount', 'effect2amount',
                 'effect3amount', 'effect4amount', 'effect5amount', 'effect6amount', 'effect7amount', 'effect8amount', 'from',
                 'gold_purchasable', 'total_gold', 'req_champion', 'special_recipe', 'stacks', 'flat_armor_mod',
                 'flat_crit_chance_mod', 'flat_hp_pool_mod', 'flat_hp_regen_mod', 'flat_magic_dmg_mod', 'flat_ms_mod',
                 'flat_phys_dmg_mod', 'flat_spellblock_mod', 'flat_pct_atk_speed_mod', 'pct_lifesteal_mod', 'pct_movespeed_mod',
                  'tags']
lol_items_df = json_normalize(data=lol_items_json['data'].values())[item_cols]
lol_items_df.columns = item_col_names
lol_items_df.head()
# Out:
#                       name                                        description  \
# 0       Skirmisher's Sabre  <groupLimit>Limited to 1 Gold Income or Jungle...
# 1          Heart of Targon  <stats>+60 Health<br>+50% Base Health Regen <b...
# 2  Philosopher's Medallion  <stats>+10% Cooldown Reduction<br>+50% Base He...
# 3                Salvation  <stats><font color='#FFFFFF'>+300 Health</font...
# 4               Ghost Poro  <subtitleLeft><font color='#FFFFFF'>(Trinket)<...
#
#   consumed  base_gold  depth     sr effect1amount effect2amount effect3amount  \
# 0      NaN        300      2   True            80            30             5
# 1      NaN        400    NaN  False           200            25             2
# 2      NaN        450    NaN  False            40            10             3
# 3      NaN        500      4   True           0.1            10            20
# 4     True          0    NaN  False           240           3.5            42
#
#   effect4amount                        ...                          \
# 0             8                        ...
# 1             0                        ...
# 2             0                        ...
# 3           0.1                        ...
# 4           NaN                        ...
#
#   flat_hp_pool_mod flat_hp_regen_mod flat_magic_dmg_mod flat_ms_mod  \
# 0              NaN               NaN                NaN         NaN
# 1               60               NaN                NaN         NaN
# 2              NaN               NaN                NaN         NaN
# 3              300               NaN                NaN         NaN
# 4              NaN               NaN                NaN         NaN
#
#   flat_phys_dmg_mod flat_spellblock_mod  flat_pct_atk_speed_mod  \
# 0               NaN                 NaN                     NaN
# 1               NaN                 NaN                     NaN
# 2               NaN                 NaN                     NaN
# 3               NaN                 NaN                     NaN
# 4               NaN                 NaN                     NaN
#
#   pct_lifesteal_mod  pct_movespeed_mod  \
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
#
#                                                 tags
# 0              [LifeSteal, ManaRegen, OnHit, Jungle]
# 1         [Health, HealthRegen, Aura, GoldPer, Lane]
# 2  [HealthRegen, ManaRegen, GoldPer, CooldownRedu...
# 3  [Health, HealthRegen, ManaRegen, CooldownReduc...
# 4                          [Vision, Trinket, Active]
#
# [5 rows x 32 columns]

# %% [markdown]
# As with the champion dataframe, I need to set the set the index separately.

# %%
lol_items_df_idx = [str(key) for key in lol_items_json['data'].keys()]
lol_items_df.index = lol_items_df_idx
lol_items_df.index = lol_items_df.index.rename('item_id')

# %%
# Filter for only Summoner's Rift items
lol_items_df = lol_items_df[lol_items_df['sr'] == True].fillna(0)
lol_items_df = lol_items_df.sort_index()

# Here is what the data looks like now
lol_items_df.head()
# Out:
#                       name                                        description  \
# item_id
# 1001        Boots of Speed  <groupLimit>Limited to 1 pair of boots.</group...
# 1004          Faerie Charm  <stats><mana>+25% Base Mana Regen </mana></stats>
# 1006     Rejuvenation Bead             <stats>+50% Base Health Regen </stats>
# 1011          Giant's Belt                         <stats>+380 Health</stats>
# 1026         Blasting Wand                   <stats>+40 Ability Power</stats>
#
#         consumed  base_gold  depth    sr effect1amount effect2amount  \
# item_id
# 1001           0        300      0  True             0             0
# 1004           0        125      0  True             0             0
# 1006           0        150      0  True             0             0
# 1011           0        600      2  True             0             0
# 1026           0        850      0  True             0             0
#
#         effect3amount effect4amount      ...       flat_hp_pool_mod  \
# item_id                                  ...
# 1001                0             0      ...                      0
# 1004                0             0      ...                      0
# 1006                0             0      ...                      0
# 1011                0             0      ...                    380
# 1026                0             0      ...                      0
#
#         flat_hp_regen_mod flat_magic_dmg_mod flat_ms_mod flat_phys_dmg_mod  \
# item_id
# 1001                    0                  0          25                 0
# 1004                    0                  0           0                 0
# 1006                    0                  0           0                 0
# 1011                    0                  0           0                 0
# 1026                    0                 40           0                 0
#
#         flat_spellblock_mod  flat_pct_atk_speed_mod pct_lifesteal_mod  \
# item_id
# 1001                      0                       0                 0
# 1004                      0                       0                 0
# 1006                      0                       0                 0
# 1011                      0                       0                 0
# 1026                      0                       0                 0
#
#          pct_movespeed_mod           tags
# item_id
# 1001                     0        [Boots]
# 1004                     0    [ManaRegen]
# 1006                     0  [HealthRegen]
# 1011                     0       [Health]
# 1026                     0  [SpellDamage]
#
# [5 rows x 32 columns]

# %% [markdown]
# This is what an item's data looks like from the dataframe.

# %%
lol_items_df.loc['2010', :]
# Out:
# name                                      Total Biscuit of Everlasting Will
# description               <consumable>Click to Consume:</consumable> Res...
# consumed                                                               True
# base_gold                                                                75
# depth                                                                     0
# sr                                                                     True
# effect1amount                                                            15
# effect2amount                                                             0
# effect3amount                                                             0
# effect4amount                                                             0
# effect5amount                                                             0
# effect6amount                                                             0
# effect7amount                                                             0
# effect8amount                                                             0
# from                                                                      0
# gold_purchasable                                                      False
# total_gold                                                               75
# req_champion                                                              0
# special_recipe                                                            0
# stacks                                                                   10
# flat_armor_mod                                                            0
# flat_crit_chance_mod                                                      0
# flat_hp_pool_mod                                                          0
# flat_hp_regen_mod                                                         0
# flat_magic_dmg_mod                                                        0
# flat_ms_mod                                                               0
# flat_phys_dmg_mod                                                         0
# flat_spellblock_mod                                                       0
# flat_pct_atk_speed_mod                                                    0
# pct_lifesteal_mod                                                         0
# pct_movespeed_mod                                                         0
# tags                                                                     []
# Name: 2010, dtype: object

# %% [markdown]
# Clean the item table. I think I can just fill all NaNs with 0.

# %% [markdown]
# ## Match Data Acquisition

# %% [markdown]
# Need random players in Platinum and Diamond leagues, and random ranked games from their history. Then get all that match data, and boil it down with the same logic that I used above.

# %% [markdown]
# To start, I need to find the Platinum and Diamond leagues.
#
# League IDs from plat and diamond leagues. I found a csv file on a thread (https://discussion.developer.riotgames.com/questions/5696/how-to-get-all-leagueid.html) with a player-made database of league IDs by region (http://canisback.com/leagueId/ ). I downloaded 'league_na1.csv' and renamed it to 'league_ids_na1.csv'

# %%
league_id_df = pd.read_csv('../data/league_ids_na1.csv')
league_id_df.head()
# Out:
#                                leagueId      tier  number
# 0  000115d0-45ad-11e8-a09c-c81f66dbb56c      GOLD     200
# 1  000220d0-8ac5-11e8-ae23-c81f66cf2333    SILVER     200
# 2  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM     105
# 3  000707c0-35df-11e8-a82d-c81f66cf2333      GOLD     200
# 4  0010adb0-04a8-11e8-9e8c-c81f66cf135e    SILVER     200

# %%
league_id_df.groupby('tier').size()
# Out:
# tier
# BRONZE        1438
# CHALLENGER       1
# DIAMOND        222
# GOLD          2926
# MASTER           1
# PLATINUM       881
# SILVER        4546
# dtype: int64

# %% [markdown]
# Keep Diamond and Platinum league IDs

# %%
diamond_plat_ids = league_id_df[(league_id_df['tier'] == 'PLATINUM') | (league_id_df['tier'] == 'DIAMOND')]
len(diamond_plat_ids)
# Out:
# 1103

# %%
diamond_plat_ids.head()
# Out:
#                                 leagueId      tier  number
# 2   000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM     105
# 6   001eef10-0467-11e8-a61f-c81f66cf2333   DIAMOND     200
# 40  00d11cd0-d775-11e8-8841-c81f66cf2333  PLATINUM     112
# 41  00d1b910-d775-11e8-8841-c81f66cf2333  PLATINUM     167
# 42  00d1b911-d775-11e8-8841-c81f66cf2333  PLATINUM     104

# %% [markdown]
# Build a list of players from the selected league IDs. This takes a couple minutes.

# %%
players_list_per_league = []
for leagueId in diamond_plat_ids['leagueId']:
    league_players = requests.get('https://na1.api.riotgames.com/lol/league/v4/leagues/' + leagueId, params=params)
    players_list_per_league.append(json_normalize(diamond_plat_players.json(), record_path='entries', meta=['leagueId', 'tier']))

# %%
len(players_list_per_league)
# Out:
# 1103

# %%
players_per_league_df = pd.concat(players_list_per_league)
players_per_league_df = players_per_league_df.reset_index(drop=True)
len(players_per_league_df)
# Out:
# 118021

# %% [markdown]
# Wow! 118k players.

# %%
players_per_league_df.head(2)
# Out:
#   freshBlood hotStreak inactive  leaguePoints  losses miniSeries rank  \
# 0      False     False    False             7     156        NaN    V
# 1      False     False    False            87      90        NaN   IV
#
#                                         summonerId summonerName veteran  wins  \
# 0  XeLmUgisomeVZV5sxnPZ_i_rvy3tY6UzTuwWMVF_6oqDXQ4     JohnLaeE   False   169
# 1  9tt-xsc6lJWaklLQb3cZ67JjKT9as9Twe2lhC6zLZ_ZbR54       ALEDSO   False   134
#
#                                leagueId      tier
# 0  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 1  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM

# %% [markdown]
# Save the table of players so that I don't have to do this again.

# %%
players_per_league_df.to_csv('../data/summonerIds.csv', encoding='utf-8')

# %% [markdown]
# Read table of players.

# %%
players_per_league_df = pd.read_csv('../data/summonerIds.csv', encoding='utf-8', index_col=0)
players_per_league_df.head()
# Out:
#   freshBlood hotStreak inactive  leaguePoints  losses miniSeries rank  \
# 0      False     False    False             7     156        NaN    V
# 1      False     False    False            87      90        NaN   IV
# 2      False      True    False             0     119        NaN    V
# 3      False     False    False            34      47        NaN    V
# 4      False     False    False             2      32        NaN    V
#
#                                         summonerId      summonerName veteran  \
# 0  XeLmUgisomeVZV5sxnPZ_i_rvy3tY6UzTuwWMVF_6oqDXQ4          JohnLaeE   False
# 1  9tt-xsc6lJWaklLQb3cZ67JjKT9as9Twe2lhC6zLZ_ZbR54            ALEDSO   False
# 2  ArNNtm1KFNm6f0OVQAY_hHUBeoqXXYrRWloV337NZPoKjtc  Cute School Girl   False
# 3  1904JnVQBXOoScRAwJ0_suX0YInL7kkk4dgZ_q3-XobUqIs     iHardScop3ftw   False
# 4  5oDyD3ShWA_nuiNWGLv9DjD6R1pYvT5W19aqFGySRp2QzQw          TieuTieu   False
#
#    wins                              leagueId      tier
# 0   169  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 1   134  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 2   135  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 3    59  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 4    51  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM

# %% [markdown]
# Select a random subset of players

# %%
players_sample = players_per_league_df.sample(n=1000, axis='index')
players_sample.head()
# Out:
#       freshBlood hotStreak inactive  leaguePoints  losses miniSeries rank  \
# 80474      False     False    False            17     189        NaN    V
# 17929      False     False    False             0      19        NaN    V
# 18681      False     False    False             0      55        NaN    V
# 62432      False     False    False            20      64        NaN    V
# 48086      False     False    False             0     102        NaN    V
#
#                                             summonerId     summonerName  \
# 80474  oTj32GWP1eKnScdkiY4JOE-ae_P8_tn8Yw3sdyOVBxxk5Ts       RedShowbiz
# 17929     QemJEsvrcRlshgRKqeOye-nYdkOruPu8eyKIutboo5zj         2needles
# 18681  LGexYmt0TgiRPUDZfxuONHiPHjwpWve-O8KQwgDuU9Is0c4     secret house
# 62432  6yuSAEsz1st_5y5irj-TPGkdf2VQOyn0QlRbGb040f8-zYo             Xiqe
# 48086  IzJh2jHnpR3yE8AnralfaBecT6tzeBi6eOi6wJ1e5baPGow  BigJiggleyBooBs
#
#       veteran  wins                              leagueId      tier
# 80474   False   180  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 17929   False    29  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 18681   False    59  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 62432   False    63  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM
# 48086   False   139  000305f0-dc2c-11e8-b3fa-c81f66dbb56c  PLATINUM

# %%
len(players_sample)
# Out:
# 1000

# %% [markdown]
# From summonerID, get accountID. Started 1000 requests at 12:58, finished in maybe 5 min.

# %%
account_id_list = []
for summonerId in players_sample['summonerId']:
    account = requests.get('https://na1.api.riotgames.com/lol/summoner/v4/summoners/' + summonerId, params=params)
    account_id_list.append(json_normalize(account.json()))

# %%
len(account_id_list)
# Out:
# 1000

# %%
account_id_df = pd.concat(account_id_list)
account_id_df.head()
# Out:
#                                          accountId  \
# 0  jcca11rEECVt92_fO-wROSTXjfe8Hg4QsFYLawdcz51Sazo
# 0      trDelhyIAQafBMCRfNN1GES4ZQoosvnAy1P1acEVziw
# 0  qF_ruKGLkMWEMNFEZ_zIt-1X9mJJ3v8NUNRxcyBkReccFRM
# 0   WmjmGrn29WyhsLpkIkAqfnDDJtbA5hbrJt1qZAIiiWaBzw
# 0  Cq0YZy3jXTMpp8j8AccpkjSLOtn5r8go5M1sxqAR6TKFtso
#
#                                                 id             name  \
# 0  oTj32GWP1eKnScdkiY4JOE-ae_P8_tn8Yw3sdyOVBxxk5Ts       RedShowbiz
# 0     QemJEsvrcRlshgRKqeOye-nYdkOruPu8eyKIutboo5zj         2needles
# 0  LGexYmt0TgiRPUDZfxuONHiPHjwpWve-O8KQwgDuU9Is0c4     secret house
# 0  6yuSAEsz1st_5y5irj-TPGkdf2VQOyn0QlRbGb040f8-zYo             Xiqe
# 0  IzJh2jHnpR3yE8AnralfaBecT6tzeBi6eOi6wJ1e5baPGow  BigJiggleyBooBs
#
#    profileIconId                                              puuid  \
# 0              0  1Tq_gJJqWlD3v9ZIOepd3FOLpPqWHwnZ9wtyzNBSHLQA0f...
# 0              8  gxIfoAubGK4gZJ256bDo1A_alBthIF-kSMRlRzeCR5JOaa...
# 0           3175  bgxEYrLbTXn8hz11Qm56qDqGhG4ngA5o0M0BVjLN2_3GHX...
# 0           3795  6liYKrxX-1J1gmsqpLPuR8nSw08B05MrTitAg-LF6H04fe...
# 0              7  56TM7Y9fOoMYb-BJFMIzwH8J5Hc-PzqFg7z6s2I1NbCCtw...
#
#    revisionDate status.message  status.status_code  summonerLevel
# 0  1.543955e+12            NaN                 NaN             61
# 0  1.541031e+12            NaN                 NaN             35
# 0  1.540939e+12            NaN                 NaN             52
# 0  1.543815e+12            NaN                 NaN             93
# 0  1.543204e+12            NaN                 NaN             87

# %%
len(account_id_df)
# Out:
# 1000

# %% [markdown]
# Get match history for each player.

# %%
match_history_list = []
for accountId in account_id_df['accountId']:
    match_history = requests.get('https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/' + str(accountId) + '?queue=420',
                                params=params)
    if 'matches' in match_history.json():
        match_history_list.append(json_normalize(match_history.json()['matches']))
    time.sleep(1.2)

# %%
len(match_history_list)
# Out:
# 196

# %%
match_history_df = pd.concat(match_history_list)
len(match_history_df)
# Out:
# 18091

# %% [markdown]
# Make a set of the gameIds, then get match data from gameId. gameId is long, need to convert to int and then to str

# %%
match_history_df.head()
# Out:
#    champion      gameId  lane platformId  queue         role  season  \
# 0       126  2924316053   MID        NA1    420         SOLO      11
# 1       126  2924333379  NONE        NA1    420  DUO_SUPPORT      11
# 2       126  2924193158   MID        NA1    420         SOLO      11
# 3       126  2924177627   MID        NA1    420          DUO      11
# 4       126  2924029423   MID        NA1    420         SOLO      11
#
#        timestamp
# 0  1543952595125
# 1  1543951246581
# 2  1543908576060
# 3  1543906450796
# 4  1543893366771

# %% [markdown]
# Take a random sample of 1000 games from the match dataframe. Make sure the game IDs are unique, in case some players in my random sample of players faced each other.

# %%
game_ids = match_history_df.sample(n=1000, axis='index')['gameId'].unique()

# %% [markdown]
# Make list of dataframes for each match, then turn into one big dataframe? Rate limits mean that fetching ~900 games should take 40 min

# %%
game_ids[0:10]
# Out:
# array([2855810690, 2894635369, 2792282086, 2842012227, 2889141116,
#        2907087506, 2892832264, 2893954890, 2898065427, 2907077614], dtype=int64)

# %%
def get_item_timestamp( match_df, timing_df, participant_id, item_num ):
    
    col_name = 'stats.item' + str(item_num)
    blacklisted_item_ids = [2424, 3340, 2421, 3042, 2422, 3040, 2403, 3513, 2010]
    item_id = match_df[match_df['participantId'] == participant_id][col_name].values[0]
        
    if (match_df.loc[participant_id - 1, col_name] == 0) or (item_id in blacklisted_item_ids):
        return np.nan
    else:
        timestamps = timing_df[(timing_df['type'] == 'ITEM_PURCHASED') &
                         (timing_df['participantId'] == participant_id) &
                         (timing_df['itemId'] ==
                          match_df[match_df['participantId'] == participant_id][col_name].values[0]
                          )]['timestamp']
        if len(timestamps) == 0:
            return np.nan
        else:
            return timestamps.values[-1]

# %% [markdown]
# Here is the big request loop.
#
# For each game ID, I get the match data, normalized properly, and join the timing data to it.
#
# Also need to be sure to not violate my API key's request rate of 100 requests per 2 minutes.

# %%
match_data_list = []
item_timing_col_names = ['participantId', 'item0_time', 'item1_time', 'item2_time',
                         'item3_time', 'item4_time', 'item5_time', 'item6_time']
match_data
for game_id in game_ids:
    # Requests
    match_data = requests.get('https://na1.api.riotgames.com/lol/match/v4/matches/' + str(game_id), params=params)
    match_timeline = requests.get('https://na1.api.riotgames.com/lol/match/v4/timelines/by-match/' + str(game_id), params=params)
    
    # Dataframes
    if ('status' in match_timeline.json() and match_timeline.json()['status']['status_code'] == 404):
        continue
    
    timeline_df = json_normalize(match_timeline.json(), ['frames', 'events'])
    timeline_df = timeline_df[['participantId', 'itemId', 'timestamp', 'type']]
    
    match_data_df = json_normalize(match_data.json()['participants']).sort_values('participantId')
    
    item_timing_cols = pd.DataFrame(index=np.arange(1,11), columns=item_timing_col_names)
    
    # Fill in item_timing_cols
    for participant_id in match_data_df['participantId']:
    # 7 possible final items with wards
        item_timing_cols.loc[participant_id, 'participantId'] = participant_id
        item_timing_cols.loc[participant_id, 'item0_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 0)
        item_timing_cols.loc[participant_id, 'item1_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 1)
        item_timing_cols.loc[participant_id, 'item2_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 2)
        item_timing_cols.loc[participant_id, 'item3_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 3)
        item_timing_cols.loc[participant_id, 'item4_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 4)
        item_timing_cols.loc[participant_id, 'item5_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 5)
        item_timing_cols.loc[participant_id, 'item6_time'] = get_item_timestamp(match_data_df, timeline_df, participant_id, 6)
    
    match_data_with_timing_df = match_data_df.join(item_timing_cols, on='participantId', lsuffix='_l', rsuffix='_r')
    
    match_data_list.append(match_data_with_timing_df)
    time.sleep(2.5)

# %%
len(match_data_list)
# Out:
# 925

# %%
matches_df = pd.concat(match_data_list)

# %% [markdown]
# Here is the final dataframe!

# %%
matches_df.head(10)
# Out:
#    championId highestAchievedSeasonTier item0_time item1_time item2_time  \
# 0         103                    SILVER    1442408    1317001    1097684
# 1         267                    SILVER    1145366    1584846     566750
# 2          24                  UNRANKED     704373    1326581     959447
# 3          61                  PLATINUM    1170289     805550    1953211
# 4          41                      GOLD    1592110     644571    1142726
# 5          80                  UNRANKED      15125     763991    1318684
# 6          51                      GOLD    1840722     604770    1507416
# 7          99                  UNRANKED     939744     554210    1239105
# 8         111                      GOLD     554507    1443795    1905387
# 9          64                      GOLD    1903638     977667    1623427
#
#   item3_time item4_time item5_time item6_time masteries  \
# 0        NaN    1955521    1859933        NaN       NaN
# 1    1916517    1956258    1956258        NaN       NaN
# 2    1989154        NaN        NaN        NaN       NaN
# 3    1656055    1168408    1959599        NaN       NaN
# 4    1834880        NaN        NaN        NaN       NaN
# 5    1185242    1646738    1777846        NaN       NaN
# 6     788646    1158770    1651397        NaN       NaN
# 7    1486997    1885613        NaN        NaN       NaN
# 8     789306    1907371    1907371    1240392       NaN
# 9     571074    1347487    1907239        NaN       NaN
#
#                 ...                timeline.participantId timeline.role  \
# 0               ...                                     1     DUO_CARRY
# 1               ...                                     2   DUO_SUPPORT
# 2               ...                                     3          NONE
# 3               ...                                     4          SOLO
# 4               ...                                     5          SOLO
# 5               ...                                     6          SOLO
# 6               ...                                     7     DUO_CARRY
# 7               ...                                     8          SOLO
# 8               ...                                     9   DUO_SUPPORT
# 9               ...                                    10          NONE
#
#   timeline.xpDiffPerMinDeltas.0-10  timeline.xpDiffPerMinDeltas.10-20  \
# 0                            -19.3                             -24.55
# 1                            -19.3                             -24.55
# 2                            -43.7                             -79.20
# 3                             13.0                            -131.10
# 4                            -18.2                            -190.30
# 5                             18.2                             190.30
# 6                             19.3                              24.55
# 7                            -13.0                             131.10
# 8                             19.3                              24.55
# 9                             43.7                              79.20
#
#    timeline.xpDiffPerMinDeltas.20-30  timeline.xpDiffPerMinDeltas.30-end  \
# 0                             -50.25                                 NaN
# 1                             -50.25                                 NaN
# 2                              -2.30                                 NaN
# 3                              60.50                                 NaN
# 4                              69.40                                 NaN
# 5                             -69.40                                 NaN
# 6                              50.25                                 NaN
# 7                             -60.50                                 NaN
# 8                              50.25                                 NaN
# 9                               2.30                                 NaN
#
#    timeline.xpPerMinDeltas.0-10  timeline.xpPerMinDeltas.10-20  \
# 0                         332.5                          458.8
# 1                         306.0                          294.8
# 2                         285.1                          459.3
# 3                         490.0                          434.0
# 4                         411.9                          428.6
# 5                         430.1                          618.9
# 6                         392.3                          503.8
# 7                         477.0                          565.1
# 8                         284.8                          298.9
# 9                         328.8                          538.5
#
#    timeline.xpPerMinDeltas.20-30  timeline.xpPerMinDeltas.30-end
# 0                          424.8                             NaN
# 1                          424.2                             NaN
# 2                          558.5                             NaN
# 3                          474.4                             NaN
# 4                          511.5                             NaN
# 5                          442.1                             NaN
# 6                          623.2                             NaN
# 7                          413.9                             NaN
# 8                          326.3                             NaN
# 9                          560.8                             NaN
#
# [10 rows x 151 columns]

# %%
matches_df.to_csv('../data/match_data_2.csv', encoding='utf-8')

# %%
matches_df = pd.read_csv('../data/match_data_2.csv', encoding='utf-8', index_col=0)

# %%
matches_df.head()
# Out:
#    championId highestAchievedSeasonTier  item0_time  item1_time  item2_time  \
# 0         103                    SILVER     1442408     1317001     1097684
# 1         267                    SILVER     1145366     1584846      566750
# 2          24                  UNRANKED      704373     1326581      959447
# 3          61                  PLATINUM     1170289      805550     1953211
# 4          41                      GOLD     1592110      644571     1142726
#
#    item3_time  item4_time  item5_time  item6_time masteries  \
# 0         NaN     1955521     1859933         NaN       NaN
# 1     1916517     1956258     1956258         NaN       NaN
# 2     1989154         NaN         NaN         NaN       NaN
# 3     1656055     1168408     1959599         NaN       NaN
# 4     1834880         NaN         NaN         NaN       NaN
#
#                 ...                timeline.participantId  timeline.role  \
# 0               ...                                     1      DUO_CARRY
# 1               ...                                     2    DUO_SUPPORT
# 2               ...                                     3           NONE
# 3               ...                                     4           SOLO
# 4               ...                                     5           SOLO
#
#   timeline.xpDiffPerMinDeltas.0-10  timeline.xpDiffPerMinDeltas.10-20  \
# 0                            -19.3                             -24.55
# 1                            -19.3                             -24.55
# 2                            -43.7                             -79.20
# 3                             13.0                            -131.10
# 4                            -18.2                            -190.30
#
#    timeline.xpDiffPerMinDeltas.20-30  timeline.xpDiffPerMinDeltas.30-end  \
# 0                             -50.25                                 NaN
# 1                             -50.25                                 NaN
# 2                              -2.30                                 NaN
# 3                              60.50                                 NaN
# 4                              69.40                                 NaN
#
#    timeline.xpPerMinDeltas.0-10  timeline.xpPerMinDeltas.10-20  \
# 0                         332.5                          458.8
# 1                         306.0                          294.8
# 2                         285.1                          459.3
# 3                         490.0                          434.0
# 4                         411.9                          428.6
#
#    timeline.xpPerMinDeltas.20-30  timeline.xpPerMinDeltas.30-end
# 0                          424.8                             NaN
# 1                          424.2                             NaN
# 2                          558.5                             NaN
# 3                          474.4                             NaN
# 4                          511.5                             NaN
#
# [5 rows x 151 columns]

# %%
len(matches_df)
# Out:
# 9250
