# %% [markdown]
# # League of Legends Item Balancing
#
# ### Capstone Project 1: Exploratory Data Analysis
#
# This is the same process as the original project, only newer data.
#
# The overarching question: How would a developer for this game know when they need to change an item?
#
# This notebook visualizes data and does some statistical tests to see if items can be classified as too strong or too weak, and thus be worthy or rebalancing.

# %% [markdown]
# ## Data
#
# Champions: This is information on the playable characters in the game.
#
# Items: This is information on the purchasable items in the game.
#
# Match Data: This is information on games themselves, including played champions, final items bought, when the final items were bought, etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import re
import seaborn as sns

# %matplotlib inline
sns.set()

# %%
from itertools import product

leagues = ['GOLD', 'PLATINUM', 'DIAMOND']
divisions = ['IV', 'III', 'II', 'I']

leagues_and_divisions = list(product(leagues, divisions))
leagues_and_divisions
# Out:
# [('GOLD', 'IV'),
#  ('GOLD', 'III'),
#  ('GOLD', 'II'),
#  ('GOLD', 'I'),
#  ('PLATINUM', 'IV'),
#  ('PLATINUM', 'III'),
#  ('PLATINUM', 'II'),
#  ('PLATINUM', 'I'),
#  ('DIAMOND', 'IV'),
#  ('DIAMOND', 'III'),
#  ('DIAMOND', 'II'),
#  ('DIAMOND', 'I')]

# %% [markdown]
# ### Load in Data

# %%
champions_min_df = pd.read_csv('../data/champions_min_9.8.1.csv', index_col=0)
filter(lambda x: x != 'u', re.findall('[A-Za-z]\w*', champions_min_df.loc['Jax', 'tags']))
champions_min_df['tags'] = [filter(lambda x: x != 'u', re.findall('[A-Za-z]\w*', champions_min_df.loc[champion, 'tags']))\
                            for champion in champions_min_df.index]
champions_min_df.head(2)
# Out:
#                  name          id  key                 tags  info.attack  \
# champion_name
# MonkeyKing     Wukong  MonkeyKing   62      [Fighter, Tank]            8
# Jax               Jax         Jax   24  [Fighter, Assassin]            7
#
#                info.defense  info.difficulty  info.magic
# champion_name
# MonkeyKing                5                3           2
# Jax                       5                5           7

# %%
champions_min_df.loc['Jax', 'tags']
# Out:
# ['Fighter', 'Assassin']

# %%
items_df = pd.read_csv('../data/items_9.8.1.csv', encoding='utf-8', index_col=0)
filter(lambda x: x != 'u', re.findall('[A-Za-z]\w*', items_df.loc[3800, 'tags']))
items_df['tags'] = [filter(lambda x: x != 'u', re.findall('[A-Za-z]\w*', items_df.loc[item_id, 'tags']))\
                    for item_id in items_df.index]
items_df.head(2)
# Out:
#                    name                                        description  \
# item_id
# 1001     Boots of Speed  <groupLimit>Limited to 1 pair of boots.</group...
# 1004       Faerie Charm  <stats><mana>+25% Base Mana Regen </mana></stats>
#
#         consumed  base_gold  depth    sr  effect1amount  effect2amount  \
# item_id
# 1001           0        300    0.0  True            0.0            0.0
# 1004           0        125    0.0  True            0.0            0.0
#
#          effect3amount  effect4amount    ...      flat_hp_regen_mod  \
# item_id                                  ...
# 1001               0.0            0.0    ...                    0.0
# 1004               0.0            0.0    ...                    0.0
#
#          flat_magic_dmg_mod  flat_ms_mod  flat_phys_dmg_mod  \
# item_id
# 1001                    0.0         25.0                0.0
# 1004                    0.0          0.0                0.0
#
# ...

# %%
items_df.loc[1001, 'tags']
# Out:
# [u'Boots']

# %%
item_occ = pd.read_csv('../data/item_stats_ALL.csv', encoding='utf-8', index_col=0)
item_occ = item_occ.join(items_df[['name', 'full_item', 'total_gold', 'tags']])
item_occ.head(2)
# Out:
#          count  pick_rate  spread     wins  win_rate            name  \
# item_id
# 0        79652   0.568245     144  34236.0  0.429820             NaN
# 1001      6182   0.044103     143   2189.0  0.354093  Boots of Speed
#
#         full_item  total_gold     tags
# item_id
# 0             NaN         NaN      NaN
# 1001        False       300.0  [Boots]

# %% [markdown]
# # Inferential Statistics Questions
#
#
# ## What are the variables most relevant to the final question?
#
# In order: win rate, pick rate, champion spread.
#
# Win Rate is the easier Bernoulli variable to determine performance. A win rate that deviates considerably from the norm will indicate a poorly balanced item, and suggest that the item be changed. Items with low win rates should be stronger, and items with high win rates should be weaker.
#
# Pick Rate is almost a Bernoulli variable (if I divide it by 7, it will be. This is because there are 7 item slots, which influenced how I did the original calculation). High pick rates indicate a relative popularity of an item, and may indicate what appears to be strong. Items with pick rates that are too high make the game stale, and should be weaker. Similarly, if many items aren't picked much at all, then the variety they bring to the game is nonexistent, and they should be stronger. Some of this has to do with the game meta, or what players feel is the most viable strategy for most games.
#
# Champion Spread is a measure of how many unique champions build an item. It could be turned into the proportion of champions that build each item by dividing by 141. It is related to Pick Rate, as it is more likely that an item gets built if many different champions can build it and have a decent chance of winning. This variable should be paired with tags to see if there are lots of unexpected champions building items.
#
# ## Are there strong correlations between pairs of independent variables or between an independent and a dependent variable?
#
# Pick rate and champion spread.
#
# Win rate and item cost (only if I include incomplete items. The set of full items has much less correlation between these two).
#
# ## What are the most appropriate tests to use to analyse these relationships?
#
# Z-test for the proportion of wins (win rate) vs the mean.
#
# Z-test for the proportion of picks (pick rate) vs the mean?

# %% [markdown]
# ## Potential Hypothesis Tests
#
# ### Use alpha = 0.05
#
# (DONE) The win rate of each item is the same (establish mean of finished items, then compare to that).
#
# (DONE) The win rate of each tag is the same (compare to mean found earlier).
#
# (DONE) High win rate correlates with high pick rate. (not a test tho?)
#
# (DONE) High pick rate correlates with high champion spread. (not a test tho?)
#
# Building items earlier increases your win rate (power spike) (probably easier to do with Machine Learning).
#
# Items with high champion spread (especially with champions outside the normal tag) are too powerful.

# %% [markdown]
# ## Further Work Plotting
#
# Can plot quantities over all leagues, then show the values for individual leagues / divisions.
#
# Plot average win rates with std, find stds for individual leagues / divisions as well.

# %% [markdown]
# ## Notes
#
# Probably won't include boots, trinkets, in the analysis. Could maybe do a small analysis on peripheral tags.

# %% [markdown]
# ## Edge Case Elimination
#
# Cut out consumables, lane items, boots, trinkets, and other edge case items I don't want in the analysis. These items are  biased against because I only look at inventories at the end of the game or have too high of pick rates, so their win rates are much more centered around 0.5.
#
# Don't include jungle items for now. They don't mirror the same distribution as the rest of the full items.

# %%
consumable = [True if (type(tags) == list and 'Consumable' in tags) else False for tags in item_occ['tags']]

lane_items = [True if (type(tags) == list and 'Lane' in tags) else False for tags in item_occ['tags']]

boots = [True if (type(tags) == list and 'Boots' in tags) else False for tags in item_occ['tags']]

trinkets = [True if (type(tags) == list and 'Trinket' in tags) else False for tags in item_occ['tags']]

jungle_items = [True if (type(tags) == list and 'Jungle' in tags) else False for tags in item_occ['tags']]

other_no_no_ids = [2010, 2057, 2403]
other_edge_cases = [True if id in other_no_no_ids else False for id in item_occ.reset_index()['item_id']]

edge_cases = [cons or lane or other or boot or trinket or jungle for cons, lane, other, boot, trinket, jungle in
              zip(consumable, lane_items, other_edge_cases, boots, trinkets, jungle_items)]
no_edge_cases = [not case for case in edge_cases]

# %%
item_occ[other_edge_cases]
# Out:
#          count  pick_rate  spread   wins  win_rate  \
# item_id
# 2010      1107   0.007897     104  345.0  0.311653
# 2057        23   0.000164       5   10.0  0.434783
# 2403       160   0.001141      49   45.0  0.281250
#
#                                       name full_item  total_gold  \
# item_id
# 2010     Total Biscuit of Everlasting Will      True        75.0
# 2057                 Peering Farsight Ward      True        60.0
# 2403                 Minion Dematerializer      True         0.0
#
#                      tags
# item_id
# 2010                   []
# 2057     [Vision, Active]
# 2403                   []

# %% [markdown]
# ## Expanded Statistics Function
#
# This function should repeat the code for calculating average win rates, stds, etc.
#
# It will also return the filtered dataframe, so I shouldn't have to run the 3-line filter anymore.

# %% [markdown]
# ### Test: The win rate of each item is the same (establish mean of finished items, then compare to that).
#
# I build a new table to compute the difference of win rate from the mean win rate, and the standard deviation based on the win rate's status as a Bernoulli variable. I also compute the 95% confidence interval of the true win rate for each item, so I can see if it's win rate falls within an expected range.
#
# We are using an artificial population mean (idk if that is a bad idea, but it speeds up analyis) in avg_win_rate.
#
# I can take each items' win rate's standard deviation to be sqrt(p * (1 - p) / n).

# %%
def expand_df_statistics(input_df, edge_case_list, dataset_description):
    """
    Returns a modified version of input_df
    Filter based on the input edge_case_list
    Modified version of input_df will have more statistics
    """
    
    # Filter for full items, edge cases, and occurrences over 10
    output_df = input_df[(input_df['full_item'] == True) &
                         (no_edge_cases) &
                         (input_df['count'] > 10)]
    
    avg_win_rate = (output_df.loc[:, 'win_rate'] * output_df.loc[:, 'count']).sum() / output_df.loc[:, 'count'].sum()
    print("Average Win Rate (weighted) for %s is: %0.3f" % (dataset_description, avg_win_rate))
    
    # Expanded Statistics
    output_df.loc[:, 'wr_diff'] = output_df.loc[:, 'win_rate'] - avg_win_rate
    output_df.loc[:, 'wr_std'] = np.sqrt(avg_win_rate * (1 - avg_win_rate) / output_df.loc[:, 'count'])
    output_df.loc[:, 'CI95'] = output_df.loc[:, 'wr_std'] * 1.96
    
    print("Statistics Computed for %s" % dataset_description)
    
    return output_df, avg_win_rate

# %% [markdown]
# Found that none of the items found in fewer than 10 games were relevant to my analysis (Kleptomancy rewards, lane items), so I set the cutoff at 10 games. Include weight for win rates.
#
# 0.551 is the average win rate for the set of relevant full items. It is expected to be above 50% because incomplete items in a player's final inventory indicate a disadvantage, and thus a lower win rate.

# %%
overall_stats_df, overall_avg_win_rate = expand_df_statistics(item_occ, other_edge_cases, "All Matches")
# Out:
# Average Win Rate (weighted) for All Matches is: 0.551
# Statistics Computed for All Matches
# C:\Users\sebia\Miniconda2\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\sebia\Miniconda2\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ### Win Rate vs Item ID
#
# Only the relevant full items are considered here. The dotted red line is this set's average win rate of 0.547.

# %%
plt.rcParams["figure.figsize"] = (6,4)
overall_stats_df.reset_index().plot(y='win_rate', x='item_id', kind='scatter',
                                    xlim=[1000, 4500], label='data', title='Win Rate vs Item ID')

plt.plot(np.linspace(1000, 4500, 50), np.full(50, overall_avg_win_rate), 'r--', label=('%0.3f' % overall_avg_win_rate))
plt.legend(loc=2)
plt.savefig('../analysis_images/full_item_win_rate.png')

# %% [markdown]
# The 95% confidence interval is set with z-scores +/- 1.96. The table below shows the items with win rates more than 1.96 standard deviations (CI95) from the average full-item win rate. Items with a negative wr_diff are weak, and items with a positive wr_diff are strong.
#
# The figure below shows all the abnormal win-rate items.

# %%
fig_title = 'Items w/ 95% Confidence Intervals that didn\'t include ' + ('%0.3f' % overall_avg_win_rate)

plt.rcParams["figure.figsize"] = (10, 8)
anomalous_items = overall_stats_df[overall_stats_df['wr_diff'].abs() > overall_stats_df['CI95']]
anomalous_items.plot(y='wr_diff', x='name', kind='barh', xerr='wr_std',
                     color='cyan', label='Difference From Avg Win Rate',
                     title=fig_title)

plt.xlabel('Win Rate Difference From Avg ' + ('%0.3f' % overall_avg_win_rate))
plt.ylabel('Item Name')
plt.legend()
plt.tight_layout()
plt.savefig('../analysis_images/win_rate_diff_abnormal.png')

# %% [markdown]
# We can make the same figure, but with data points showing where the different leagues have their win rates.
#
# I need a function to help me get the win rate differentials.

# %%
def get_league_wr_diffs(league, avg_wr):
    """
    This function grabs the win rates from the dataframe of the appropriate league.
    It finds the difference between those win rates and the average, then returns them.
    """
    input_filepath = '../data/item_stats_' + league + '_IV_to_' + league + '_I.csv'
    league_df = pd.read_csv(input_filepath, index_col=0)
    
    wr_diffs = league_df.win_rate - avg_wr
    
    return wr_diffs

# %%
gold_wrs = get_league_wr_diffs('GOLD', overall_avg_win_rate)
plat_wrs = get_league_wr_diffs('PLATINUM', overall_avg_win_rate)
diamond_wrs = get_league_wr_diffs('DIAMOND', overall_avg_win_rate)

# %% [markdown]
# In some cases, there may be an item missing in a certain league. It isn't one of the ones we care about though, so we can get around that by slicing on the anomalous items df's index.

# %%
gold_wrs[anomalous_items.index].head(8)
# Out:
# item_id
# 3003   -0.180656
# 3004   -0.174269
# 3026    0.050750
# 3027   -0.041584
# 3030   -0.021071
# 3036    0.039109
# 3041    0.255310
# 3042   -0.061170
# Name: win_rate, dtype: float64

# %%
anomalous_items
# Out:
#          count  pick_rate  spread    wins  win_rate                     name  \
# item_id
# 3003       714   0.005094      32   311.0  0.435574        Archangel's Staff
# 3004       429   0.003061      13   154.0  0.358974                 Manamune
# 3026      7564   0.053962      92  4600.0  0.608144           Guardian Angel
# 3027      3439   0.024534      61  1805.0  0.524862              Rod of Ages
# 3030      1179   0.008411      58   614.0  0.520780          Hextech GLP-800
# 3036      1645   0.011736      57   968.0  0.588450   Lord Dominik's Regards
# 3041      2090   0.014910      86  1631.0  0.780383      Mejai's Soulstealer
# 3042      2980   0.021260      13  1502.0  0.504027                 Muramana
# 3053      6404   0.045687      59  3714.0  0.579950            Sterak's Gage
# 3068      2239   0.015973      66  1142.0  0.510049             Sunfire Cape
# 3069      3190   0.022758      41  1602.0  0.502194  Remnant of the Ascended
# ...

# %%
fig_title = 'Items w/ 95% Confidence Intervals that didn\'t include ' + ('%0.3f' % overall_avg_win_rate)

plt.rcParams["figure.figsize"] = (10, 8)
anomalous_items = overall_stats_df[overall_stats_df['wr_diff'].abs() > overall_stats_df['CI95']]
anomalous_items.plot(y='wr_diff', x='name', kind='barh', xerr='wr_std',
                     color='cyan', label='Difference From Avg Win Rate',
                     title=fig_title)

plt.plot(gold_wrs[anomalous_items.index], range(len(anomalous_items)), linestyle="",
         markersize=5, marker="o", label="Win Rate in Gold", color='gold')
plt.plot(plat_wrs[anomalous_items.index], range(len(anomalous_items)), linestyle="",
         markersize=5, marker="o", label="Win Rate in Platinum", color='grey')
plt.plot(diamond_wrs[anomalous_items.index], range(len(anomalous_items)), linestyle="",
         markersize=5, marker="o", label="Win Rate in Diamond", color='black')

plt.xlabel('Win Rate Difference From Avg ' + ('%0.3f' % overall_avg_win_rate))
plt.ylabel('Item Name')
plt.legend()
plt.tight_layout()
plt.savefig('../analysis_images/win_rate_diff_abnormal_with_leagues.png')

# %% [markdown]
# ### Test: High win rate correlates with high pick rate.
#
# This is inconclusive. The Pearson correlation coefficient for these values is 0.08. It seems as though more popular items tend to get built by both teams, and bring the win rate closer to 50%.

# %%
plt.rcParams["figure.figsize"] = (6,4)
overall_stats_df.plot(x='pick_rate', y='win_rate', kind='scatter',
                      xlim=[-0.01, 0.15], label='data', title='Win Rate vs Pick Rate')

plt.plot(np.linspace(-0.01, 0.15, 50), np.full(50, overall_avg_win_rate), 'r--', label=('%0.3f' % overall_avg_win_rate))
plt.legend()
plt.savefig('../analysis_images/full_item_win_rate_vs_pick_rate.png')

# %%
overall_stats_df.corr()#['pick_rate']['win_rate']
# Out:
#                count  pick_rate    spread      wins  win_rate  total_gold  \
# count       1.000000   1.000000  0.428482  0.998195  0.038059    0.099417
# pick_rate   1.000000   1.000000  0.428482  0.998195  0.038059    0.099417
# spread      0.428482   0.428482  1.000000  0.437810  0.207525    0.095084
# wins        0.998195   0.998195  0.437810  1.000000  0.074352    0.097462
# win_rate    0.038059   0.038059  0.207525  0.074352  1.000000   -0.058882
# total_gold  0.099417   0.099417  0.095084  0.097462 -0.058882    1.000000
# wr_diff     0.038059   0.038059  0.207525  0.074352  1.000000   -0.058882
# wr_std     -0.501323  -0.501323 -0.644878 -0.505372 -0.102865   -0.149633
# CI95       -0.501323  -0.501323 -0.644878 -0.505372 -0.102865   -0.149633
#
#              wr_diff    wr_std      CI95
# count       0.038059 -0.501323 -0.501323
# pick_rate   0.038059 -0.501323 -0.501323
# spread      0.207525 -0.644878 -0.644878
# wins        0.074352 -0.505372 -0.505372
# ...

# %%
overall_stats_df.corr()['pick_rate']['win_rate']
# Out:
# 0.0380594691030905

# %% [markdown]
# ### Test: High pick rate correlates with high champion spread.
#
# This makes sense. Correlation coefficient of 0.468.

# %%
overall_stats_df.plot(x='spread', y='pick_rate', kind='scatter', title='Pick Rate vs Champion Spread')
plt.savefig('../analysis_images/full_item_pick_rate_vs_spread.png')

# %%
overall_stats_df.corr()['pick_rate']['spread']
# Out:
# 0.42848230139182064

# %% [markdown]
# ### Test: Win Rate correlates with item cost
#
# Not really. Correlation coefficient is only 0.025

# %%
overall_stats_df.plot(x='total_gold', y='win_rate', kind='scatter', title='Win Rate vs Total Item Cost')

# %%
overall_stats_df.corr()['total_gold']['win_rate']
# Out:
# -0.058882298398667557

# %% [markdown]
# ### Jungle Item Win Rate Conundrum
#
# Generally, one person on each team is a Jungler, and will buy 1 Jungle item (particularly in the item_id range around 2500-2600). If one of these items is built per team per game, I would expect the full Jungle items to sit evenly around the average win rate.
#
# However, all the jungle items have a win rate that is on par with or below the full item avg win rate. Actually, the win rate seems to sit around 0.50. Since one player per team per game jungles, and makes a jungle item, the overall win rate for full jungle items should sit around 0.50. Incomplete jungle items are uncommon, since a player will only build 1 full jungle item, and it is generally completed first.
#
# More statistics in the table below.

# %%
no_name = [True if type(name) == float else False for name in item_occ.name]
named = [not name for name in no_name]
named_items = item_occ[named]

jungle = [True if (type(tags) == list and 'Jungle' in tags) else False for tags in named_items['tags']]
named_items[(((named_items.name.str.contains('Enchantment'))) | (jungle)) &
            (named_items['count'] > 5)].plot(x='total_gold', y='win_rate', kind='scatter',
                                             xlim=[-100, 3000], label='Jungle Items',
                                             title='Jungle Item Win Rates (Full Jungle Items on the Right)')

plt.plot(np.linspace(-100, 3000, 50), np.full(50, overall_avg_win_rate), 'r--', label=('%0.3f' % overall_avg_win_rate))
plt.plot(np.linspace(-100, 3000, 50), np.full(50, 0.50), 'k--', label='0.500')
plt.legend(loc='best')
plt.savefig('../analysis_images/full_jg_item_win_rates.png')

# %%
named_items[(((named_items.name.str.contains('Enchantment'))) | (jungle)) &
            (named_items['count'] > 5)].sort_values('win_rate', ascending=False)
# Out:
#          count  pick_rate  spread     wins  win_rate  \
# item_id
# 1419      1875   0.013376      39    973.0  0.518933
# 1416       689   0.004915      23    354.0  0.513788
# 1413      1531   0.010922      47    775.0  0.506205
# 1412      6147   0.043853      49   3099.0  0.504148
# 1400      7577   0.054055      44   3807.0  0.502442
# 1402      3035   0.021652      55   1519.0  0.500494
# 1401      4057   0.028943      49   2020.0  0.497905
# 1414       668   0.004766      31    330.0  0.494012
# 3340     70420   0.502383     144  33784.0  0.479750
# 2032       278   0.001983      58    132.0  0.474820
# 2061        47   0.000335       9     22.0  0.468085
# 2031     18882   0.134706     143   8501.0  0.450217
# 1041       680   0.004851      26    306.0  0.450000
# 1039       265   0.001891      25    114.0  0.430189
# 2062       110   0.000785      18     42.0  0.381818
# 3706       367   0.002618      48    132.0  0.359673
# ...

# %% [markdown]
# ### Test: The win rate of each tag is the same (compare to mean found earlier)
#
# This test is to see if certain kinds of items are more powerful than others, but ultimately isn't really in the spirit of finding specific items that are too strong or too weak.

# %%
tag_based_stats_df = pd.read_csv('../data/tag_based_stats_8.22.1.csv', encoding='utf-8', index_col=0)
tag_based_stats_df['std_win_rate'] = np.sqrt(overall_avg_win_rate * (1 - overall_avg_win_rate) 
                                             / tag_based_stats_df['pick_count'])
tag_based_stats_df.sort_values('avg_win_rate', ascending=False)
# Out:
#                   tag  pick_count  avg_pick_rate  avg_win_rate  \
# 12   MagicPenetration     24892.0       0.049063      0.546039
# 19             Vision      8908.0       0.063550      0.542883
# 13     CriticalStrike     48777.0       0.060891      0.542694
# 20   ArmorPenetration     49855.0       0.069981      0.535694
# 22   NonbootsMovement    114725.0       0.055959      0.534452
# 9           LifeSteal     32882.0       0.036390      0.532024
# 23               Aura     12225.0       0.021391      0.530389
# 4          SpellBlock     40731.0       0.018932      0.529891
# 3              Damage    182684.0       0.056640      0.529384
# 11             Active    109336.0       0.046730      0.528326
# 18        SpellDamage    156457.0       0.049151      0.528254
# 10          SpellVamp      5034.0       0.019872      0.527414
# 14              OnHit    128106.0       0.060233      0.523512
# 0   CooldownReduction    208444.0       0.053306      0.523445
# ...

# %%
_ = plt.rcParams["figure.figsize"] = (8,6)
_ = tag_based_stats_df.sort_values('avg_win_rate',
                                   ascending=True).plot(y='avg_win_rate', kind='barh', xerr='std_win_rate',
                                                        xlim=[0.3, 0.6], title='Item Win Rates By Tag', color='cyan',
                                                        label='Avg Win Rate')

_ = plt.axvline(overall_avg_win_rate, color='red', linestyle='--', label=('%0.3f' % overall_avg_win_rate))

locs, labels = plt.yticks()
_ = plt.yticks(locs, list(tag_based_stats_df.sort_values('avg_win_rate', ascending=True).tag))
_ = plt.legend(loc='best', borderaxespad=0.)#bbox_to_anchor=(1.05, 1), 

_ = plt.xlabel('Win Rate')
_ = plt.ylabel('Item Tag')


_ = plt.tight_layout()

plt.savefig('../analysis_images/tag_win_rates.png')

# %% [markdown]
# This shows the average win rate for each tag with a standard deviation.
#
# This is less useful because it includes incomplete items, I think.

# %%
tag_based_stats_df[(tag_based_stats_df['avg_win_rate']
                    - overall_avg_win_rate).abs() > 1.96 * tag_based_stats_df['std_win_rate']].sort_values('avg_win_rate',
                                                                                                            ascending=False)
# Out:
#                   tag  pick_count  avg_pick_rate  avg_win_rate  \
# 13     CriticalStrike     48777.0       0.060891      0.542694
# 20   ArmorPenetration     49855.0       0.069981      0.535694
# 22   NonbootsMovement    114725.0       0.055959      0.534452
# 9           LifeSteal     32882.0       0.036390      0.532024
# 23               Aura     12225.0       0.021391      0.530389
# 4          SpellBlock     40731.0       0.018932      0.529891
# 3              Damage    182684.0       0.056640      0.529384
# 11             Active    109336.0       0.046730      0.528326
# 18        SpellDamage    156457.0       0.049151      0.528254
# 10          SpellVamp      5034.0       0.019872      0.527414
# 14              OnHit    128106.0       0.060233      0.523512
# 0   CooldownReduction    208444.0       0.053306      0.523445
# 7         HealthRegen     56819.0       0.027970      0.522765
# 6              Health    162151.0       0.046555      0.522198
# ...

# %% [markdown]
# ### Summary
#
# Most of the various correlations I checked made sense, but were not very useful.
#
# The one very useful thing I did is the z-test of the win rate of individual items compared to the mean of all items. This will form one pillar of my final analysis.
